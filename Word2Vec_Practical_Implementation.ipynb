# %% [markdown]
# <a href="https://colab.research.google.com/github/arunabha-mandal-1/nlp-basics/blob/main/Word2Vec_Practical_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gensim

# %%
# @title Default title text { display-mode: "code" }
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %% [markdown]
# References: https://stackoverflow.com/questions/46433778/import-googlenews-vectors-negative300-bin

# %%
import gensim.downloader as api
wv = api.load('word2vec-google-news-300')

# %%
vec_king = wv['king']

# %%
vec_king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
vec_king.shape
# Out:
# (300,)

# %%
wv['cricket']
# Out:
# array([-3.67187500e-01, -1.21582031e-01,  2.85156250e-01,  8.15429688e-02,
#         3.19824219e-02, -3.19824219e-02,  1.34765625e-01, -2.73437500e-01,
#         9.46044922e-03, -1.07421875e-01,  2.48046875e-01, -6.05468750e-01,
#         5.02929688e-02,  2.98828125e-01,  9.57031250e-02,  1.39648438e-01,
#        -5.41992188e-02,  2.91015625e-01,  2.85156250e-01,  1.51367188e-01,
#        -2.89062500e-01, -3.46679688e-02,  1.81884766e-02, -3.92578125e-01,
#         2.46093750e-01,  2.51953125e-01, -9.86328125e-02,  3.22265625e-01,
#         4.49218750e-01, -1.36718750e-01, -2.34375000e-01,  4.12597656e-02,
#        -2.15820312e-01,  1.69921875e-01,  2.56347656e-02,  1.50146484e-02,
#        -3.75976562e-02,  6.95800781e-03,  4.00390625e-01,  2.09960938e-01,
#         1.17675781e-01, -4.19921875e-02,  2.34375000e-01,  2.03125000e-01,
#        -1.86523438e-01, -2.46093750e-01,  3.12500000e-01, -2.59765625e-01,
# ...

# %%
wv.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819188117981),
#  ('Twenty##_cricket', 0.8068488240242004),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372578382492065),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985968589783)]

# %%
wv.most_similar('happy')
# Out:
# [('glad', 0.7408890724182129),
#  ('pleased', 0.6632170677185059),
#  ('ecstatic', 0.6626912355422974),
#  ('overjoyed', 0.6599286794662476),
#  ('thrilled', 0.6514049172401428),
#  ('satisfied', 0.6437949538230896),
#  ('proud', 0.636042058467865),
#  ('delighted', 0.627237856388092),
#  ('disappointed', 0.6269949674606323),
#  ('excited', 0.6247665286064148)]

# %%
wv.similarity('king', 'man')
# Out:
# 0.22942673

# %%
wv.similarity('cricket', 'india')
# Out:
# 0.28765315

# %%
wv.similarity('hockey', 'sports')
# Out:
# 0.53541523

# %%
# Check with incorrect spelling
wv.similarity('hocky', 'sports')
# Out:
# 0.3040142

# %%
# Check with bangla words
wv.similarity('বাংলাদেশ', 'বাংলা')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-c509c919548b> in <cell line: 2>()
#       1 # Check with bangla words
# ----> 2 wv.similarity('বাংলাদেশ', 'বাংলা')
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in similarity(self, w1, w2)
#    1232
#    1233         """
# -> 1234         return dot(matutils.unitvec(self[w1]), matutils.unitvec(self[w2]))
#    1235
#    1236     def n_similarity(self, ws1, ws2):
#
# /usr/local/lib/python3.10/dist-packages/gensim/models/keyedvectors.py in __getitem__(self, key_or_keys)
#     401         """
#     402         if isinstance(key_or_keys, _KEY_TYPES):
# --> 403             return self.get_vector(key_or_keys)
#     404
#     405         return vstack([self.get_vector(key) for key in key_or_keys])
#
# ...

# %%
v = wv['king'] - wv['man'] - wv['woman']

# %%
v
# Out:
# array([-4.43359375e-01, -2.39257812e-02,  7.69653320e-02,  3.30078125e-01,
#        -2.33642578e-01,  1.12548828e-01,  4.24316406e-01, -2.30773926e-01,
#        -2.04101562e-01,  3.12751770e-01, -1.73828125e-01,  2.91015625e-01,
#        -3.07617188e-02,  2.51464844e-01, -3.88183594e-02, -3.04931641e-01,
#         3.19824219e-01, -6.40869141e-04, -4.58984375e-02,  2.60009766e-01,
#         2.96630859e-01,  1.59591675e-01,  8.86230469e-02,  8.16406250e-01,
#         2.69775391e-02,  2.47070312e-01, -2.92968750e-03, -4.63623047e-01,
#        -3.82812500e-01,  2.26196289e-01, -2.01171875e-01, -6.87255859e-02,
#         4.14062500e-01,  5.26489258e-01, -1.09375000e-01, -2.92968750e-01,
#        -5.15625000e-01,  1.81640625e-01,  9.42382812e-02, -3.46679688e-01,
#         2.64404297e-01, -1.64794922e-01, -8.69140625e-02,  1.74987793e-01,
#        -1.07421875e-02,  2.00683594e-01,  4.24804688e-02, -1.26953125e-02,
# ...

# %%
v.shape
# Out:
# (300,)

# %%
wv.most_similar([v])
# Out:
# [('king', 0.4048772156238556),
#  ('kings', 0.30023127794265747),
#  ('Pansy_Ho_Chiu', 0.27302688360214233),
#  ('Hassle_Free_Lead', 0.26562565565109253),
#  ('du_Grand_Controle', 0.2622641623020172),
#  ('conf_C####_TORONTO', 0.2607021629810333),
#  ('Nickerson_Zwaan', 0.25404006242752075),
#  ('José_Luis_Villegas_jvillegas@sacbee.com', 0.24456088244915009),
#  ('Cadec_Mobius_TTS', 0.2437450885772705),
#  ('Bahrain_Sheik_Hamad', 0.23861853778362274)]
